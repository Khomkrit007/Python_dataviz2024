# %% [markdown]
# <a href="https://colab.research.google.com/github/Khomkrit007/Python_dataviz2024/blob/main/movie_indy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
movie_df = pd.read_csv('/content/drive/MyDrive/Data_viz2024_Data/IMDb Movies India.csv', encoding='latin-1') # Try 'latin-1' encoding. If it still fails, try other encodings like 'iso-8859-1'
print(movie_df.shape)
movie_df.head()
# Out:
# (15509, 10)
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %% [markdown]
# #ปี

# %%
year_df = df['Year'].value_counts()
year_df
# Out:
# Year
# (2019)    410
# (2021)    392
# (2018)    381
# (2017)    360
# (2005)    346
#          ...
# (1917)      1
# (1913)      1
# (1926)      1
# (1914)      1
# (1924)      1
# Name: count, Length: 102, dtype: int64

# %%
#year_df = df.sort_values(by = 'Year', ascending=False)
#year_df

# %%
y_df = df[df['Year'].str.contains('2019', na=False)]
y_df['Votes'] = y_df['Votes'].str.replace(',', '').fillna(0).astype(int)
# Out:
# <ipython-input-62-548e2a3b90c9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_df['Votes'] = y_df['Votes'].str.replace(',', '').fillna(0).astype(int)

# %%
plt.scatter(y_df['Votes'],y_df['Rating'],s=70*y_df['Rating'],c=y_df['Rating'],alpha=0.5)

# %%
#drop ค่า Nan
movie_df.dropna(inplace=True)
movie_df.dropna()
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  (2015)  115 min
# 15494                            Zubeidaa  (2001)  153 min
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %%
#เปลี่ยนปีให้เป็น int
movie_df['Year'] = movie_df['Year'].str.strip('()').astype(int) # ลบวงเล็บออกจากปี

# %%
movie_df['Year']
# Out:
# 1        2019
# 3        2019
# 5        1997
# 6        2005
# 8        2012
#          ...
# 15493    2015
# 15494    2001
# 15503    1989
# 15505    1999
# 15508    1998
# Name: Year, Length: 5659, dtype: int64

# %%
# แยก DataFrame ของหนัง Drama และ Action
drama_df = movie_df[(movie_df['Genre'].str.contains('Drama')) &
                     (movie_df['Year'] >= 2000) & (movie_df['Year'] <= 2021)]
action_df = movie_df[(movie_df['Genre'].str.contains('Action')) &
                     (movie_df['Year'] >= 2000) & (movie_df['Year'] <= 2021)]

# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(drama_df['Year'], drama_df['Rating'], label='Drama', alpha=0.5)
plt.scatter(action_df['Year'], action_df['Rating'], label='Action', alpha=0.5)

plt.xlabel('Year')
plt.ylabel('Rating')
plt.title('Scatter Plot of Movie Ratings (Drama vs. Action)')
plt.legend()
plt.grid(True)
plt.show()

# %%
action_df.head()
# Out:
#            Name  Year Duration                    Genre  Rating  Votes  \
# 9      @Andheri  2014  116 min  Action, Crime, Thriller     4.0     11
# 33  16 December  2002  158 min         Action, Thriller     6.9  1,235
# 34        18.11  2014  126 min                   Action     3.5     10
# 43         1971  2007  136 min       Action, Drama, War     8.1  1,892
# 51    2 October  2003  122 min  Action, Crime, Thriller     5.0     33
#
#              Director         Actor 1          Actor 2          Actor 3  \
# 9   Biju Bhaskar Nair       Augustine     Fathima Babu             Byon
# 33       Mani Shankar    Milind Soman  Danny Denzongpa   Gulshan Grover
# 34      Mohibul Haque      Rehal Khan   Gulshan Grover    Mukesh Tiwari
# 43        Amrit Sagar  Manoj Bajpayee      Ravi Kishan  Deepak Dobriyal
# 51       Sunil Tiwari   Ashutosh Rana      Rocky Verma         Saadhika
#
#                                      all_actors
# 9                   Augustine,Fathima Babu,Byon
# ...
